# %% [markdown]
# # Create dataframe of variant calls in ancestral sequence and analyze

# %%
#load necessary packages
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Import data from ancestral sequence vcf file

# %%
#Define functions needed to convert vcf file into dataframe

def vcf2tsv(vcf):
    
    file = open(vcf)
    lines = file.readlines()
    file.close()
    out_file = open('temp.tsv','w')
    
    for line in lines:
        if line[0:2] != '##':
            out_file.write(line)
    
    out_file.close()
    
    

#determines total number of reads
def list_sum(in_list):
    total = 0
    for k in range(len(in_list)):
        total = total+int(in_list[k])
    return(total)

# %%
#upload data
vcf2tsv('/Users/chrisgraves/Documents/Yeast_data/Sequencing/alignments/vcf/merged/P2-0.vcf')
parent = pd.read_csv('temp.tsv',sep='\t')
parent.columns = ['Chrom','Pos','ID','Ref','Alt','Qual','Filter','Info','Format','Unknown']


#create dict containing chromosome IDs
chrom_key = list(parent['Chrom'].unique())
chrom_num = list(['I','II','III','IV','V','VI','VII','VIII','IX','X','XI','XII','XIII','XIV','XV','XVI','MITO'])
chrom_dict = dict(zip(chrom_key,chrom_num))

parent.head()
# Out:
#             Chrom    Pos ID                    Ref                      Alt  \
# 0  ref|NC_001133|     10  .                      A                        C
# 1  ref|NC_001133|   6736  .  CAAAAAAAAAAAAAAAAAAAT  CAAAAAAAAAAAAAAAAAAAAAT
# 2  ref|NC_001133|  12594  .                      A                        T
# 3  ref|NC_001133|  12690  .                      A                        T
# 4  ref|NC_001133|  19971  .                     CT                     CCTT
#
#           Qual Filter                                               Info  \
# 0     0.000089      .  AB=0;ABP=0;AC=0;AF=0;AN=2;AO=2;CIGAR=1X;DP=6;D...
# 1   265.314000      .  AB=0;ABP=0;AC=2;AF=1;AN=2;AO=10;CIGAR=1M2I20M;...
# 2   720.182000      .  AB=0.201087;ABP=145.808;AC=1;AF=0.5;AN=2;AO=37...
# 3  1828.060000      .  AB=0.333333;ABP=50.7827;AC=1;AF=0.5;AN=2;AO=66...
# 4  3947.170000      .  AB=0;ABP=0;AC=2;AF=1;AN=2;AO=131;CIGAR=1M2I1M;...
#
#                  Format                                       Unknown
# 0  GT:DP:RO:QR:AO:QA:GL            0/0:6:4:140:2:4:0,-0.250089,-12.57
# 1  GT:DP:RO:QR:AO:QA:GL          1/1:19:0:0:10:334:-30.1609,-3.0103,0
# 2  GT:DP:RO:QR:AO:QA:GL   0/1:184:144:4808:37:1286:-99.969,0,-416.938
# 3  GT:DP:RO:QR:AO:QA:GL  0/1:198:130:4461:66:2225:-194.579,0,-395.828
# 4  GT:DP:RO:QR:AO:QA:GL      1/1:133:0:0:131:4450:-400.554,-39.4349,0

# %%
#Build dataframe of ancestral sequence
parent_df = pd.DataFrame(columns = ['Chromosome','Position','Ref','Alt','Ref_count','Alt_count','Ref_freq','Alt_freq','N_calls'])
ind=0

for index, row in parent.iterrows():
    chrom = chrom_dict[row['Chrom']] #change from ref # to chromosome # using dict
    pos = int(row['Pos'])
    ref = row['Ref']
    alt_list = row['Alt'].split(',') #split into alternate alleles
    num_alleles = len(alt_list) #determine number of alternate alleles
    merged_list = row['Format'].split(':') #determine how string of merged data is formatted
    data = row['Unknown'].split(':')
    data_dict = dict(zip(merged_list,data))
    ref_count = int(data_dict['RO'])
    alt_counts = data_dict['AO'].split(',')
    total_alt = list_sum(alt_counts)
    total_count = total_alt+ref_count
    ref_freq = float(ref_count)/float(total_count)
    for alt_ind in range(len(alt_list)):
        alt = alt_list[alt_ind]
        alt_count = alt_counts[alt_ind]
        alt_freq = float(alt_count)/float(total_count)
        parent_df.loc[ind] = (chrom,pos,ref,alt,ref_count,alt_count,ref_freq,alt_freq,total_count)
        ind = ind+1
        
parent_df.head()
# Out:
#   Chromosome  Position                    Ref                      Alt  \
# 0          I        10                      A                        C
# 1          I      6736  CAAAAAAAAAAAAAAAAAAAT  CAAAAAAAAAAAAAAAAAAAAAT
# 2          I     12594                      A                        T
# 3          I     12690                      A                        T
# 4          I     19971                     CT                     CCTT
#
#    Ref_count Alt_count  Ref_freq  Alt_freq  N_calls
# 0          4         2  0.666667  0.333333        6
# 1          0        10  0.000000  1.000000       10
# 2        144        37  0.795580  0.204420      181
# 3        130        66  0.663265  0.336735      196
# 4          0       131  0.000000  1.000000      131

# %%
#output parent df to csv
parent_df.to_csv('/Users/chrisgraves/Documents/Yeast_data/Sequencing/saved_dfs/parent_df.csv',index=False)

# %% [markdown]
# ## Check that alleles fixed in parent are also fixed in samples

# %%
alleles = pd.read_csv('/Users/chrisgraves/Documents/Yeast_data/Sequencing/saved_dfs/combined_alleles.csv')
num_alleles = alleles.shape[0]/6
print('There are %d alleles' %num_alleles)
alleles.head()
# Out:
# There are 64499 alleles
#    Unnamed: 0 Chromosome  Position               Alt  Time              Ref  \
# 0           0          I      5068  ATTTTTTTTTTTTTTC     1  ATTTTTTTTTTTTTC
# 1           1          I      5068  ATTTTTTTTTTTTTTC     3  ATTTTTTTTTTTTTC
# 2           2          I      5068  ATTTTTTTTTTTTTTC     5  ATTTTTTTTTTTTTC
# 3           3          I      5068  ATTTTTTTTTTTTTTC     7  ATTTTTTTTTTTTTC
# 4           4          I      5068  ATTTTTTTTTTTTTTC     9  ATTTTTTTTTTTTTC
#
#    Is_repeat  Read_depth  Num_ref  Num_alt  Freq_ref  Freq_alt  Qual_ref  \
# 0          1         NaN      NaN        0       NaN         0       NaN
# 1          1         NaN      NaN        0       NaN         0       NaN
# 2          1         NaN      NaN        0       NaN         0       NaN
# 3          1         NaN      NaN        0       NaN         0       NaN
# 4          1         NaN      NaN        0       NaN         0       NaN
#
#    Qual_alt Treatment  Strain
# 0       NaN         C       1
# 1       NaN         C       1
# 2       NaN         C       1
# 3       NaN         C       1
# 4       NaN         C       1

# %%
all_alleles = alleles.groupby(['Chromosome','Position','Alt'])

# %%
#script to determine whether fixed alleles in ancestor are also present in experimental samples
num_fixed_P = 0
num_fixed_samples = 0
unique2P = list()

for name, group in parent_df.groupby(['Chromosome','Position','Alt']):
    if group['Alt_freq'].iloc[0] > 0.9: #if the allele is at a frequency greater than 0.9 in the ancestor
        num_fixed_P = num_fixed_P+1
        
        chrom = name[0]
        try:
            in_samples = all_alleles.get_group((name[0],int(name[1]),name[2]))
            if in_samples['Freq_alt'].sum() > 100: #frequencies should sum to 120 if fixed at all 6 timepoints in all 120 samples
                num_fixed_samples = num_fixed_samples+1             
            else:
                print('Mutation %s not fixed in all samples' %str(name))
        except KeyError:        
            unique2P.append(((name[0],int(name[1]),name[2])))
            print('Mutation %s only found in parent' %str(name))
            
print('There are %d fixed differences between the ancestor and reference. Only %d of these differences were fixed in evolved strains' %(num_fixed_P,num_fixed_samples))
# Out:
# Mutation ('I', 6736.0, 'CAAAAAAAAAAAAAAAAAAAAAT') not fixed in all samples
# Mutation ('I', 25536.0, 'A') not fixed in all samples
# Mutation ('I', 25542.0, 'G') not fixed in all samples
# Mutation ('I', 26103.0, 'C') not fixed in all samples
# Mutation ('I', 26121.0, 'A') not fixed in all samples
# Mutation ('I', 27075.0, 'A') not fixed in all samples
# Mutation ('I', 27080.0, 'TAGTA') not fixed in all samples
# Mutation ('I', 27090.0, 'C') not fixed in all samples
# Mutation ('I', 27098.0, 'AC') not fixed in all samples
# Mutation ('I', 223165.0, 'T') not fixed in all samples
# Mutation ('II', 259764.0, 'T') not fixed in all samples
# Mutation ('II', 263153.0, 'T') not fixed in all samples
# Mutation ('II', 263158.0, 'CG') not fixed in all samples
# Mutation ('II', 263168.0, 'CT') not fixed in all samples
# Mutation ('II', 478197.0, 'C') not fixed in all samples
# Mutation ('IV', 273629.0, 'GTTTTTTTTTTTTTTTTTTTTTTC') not fixed in all samples
# Mutation ('IV', 392146.0, 'GACACACACACACACACACACACACACACC') not fixed in all samples
# Mutation ('IV', 688062.0, 'CTTTTTTTTTTTTTTTTC') not fixed in all samples
# Mutation ('IV', 1525345.0, 'G') not fixed in all samples
# Mutation ('IV', 1525351.0, 'G') not fixed in all samples
# Mutation ('IV', 1525357.0, 'G') not fixed in all samples
# Mutation ('IV', 1525363.0, 'G') not fixed in all samples
# Mutation ('IX', 18865.0, 'T') not fixed in all samples
# Mutation ('IX', 18866.0, 'G') not fixed in all samples
# Mutation ('MITO', 320.0, 'T') only found in parent
# Mutation ('MITO', 33618.0, 'TTCA') not fixed in all samples
# Mutation ('MITO', 49918.0, 'A') not fixed in all samples
# Mutation ('MITO', 49925.0, 'A') not fixed in all samples
# Mutation ('VI', 10170.0, 'G') not fixed in all samples
# Mutation ('VI', 270159.0, 'GGTG') not fixed in all samples
# Mutation ('VII', 9.0, 'C') not fixed in all samples
# Mutation ('VII', 397834.0, 'GAAAAAAAAAAAAAAAAAAAT') not fixed in all samples
# Mutation ('VII', 496729.0, 'TAAAAAAAAAAAAAAG') not fixed in all samples
# Mutation ('VII', 627186.0, 'TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTC') not fixed in all samples
# Mutation ('VIII', 21.0, 'ACCA') not fixed in all samples
# Mutation ('VIII', 236993.0, 'A') not fixed in all samples
# Mutation ('VIII', 475931.0, 'TTATATATATATATATATATAT') not fixed in all samples
# Mutation ('X', 470130.0, 'GTAATAATAATAATAATAATAATAATAATAATAATAATAATAATAAT') not fixed in all samples
# Mutation ('X', 737743.0, 'C') not fixed in all samples
# Mutation ('XII', 881947.0, 'CATATATATATATATATATATATATT') not fixed in all samples
# Mutation ('XII', 944108.0, 'C') only found in parent
# Mutation ('XII', 1071409.0, 'C') only found in parent
# Mutation ('XIII', 2126.0, 'C') not fixed in all samples
# Mutation ('XIII', 198509.0, 'A') not fixed in all samples
# Mutation ('XIII', 908203.0, 'A') not fixed in all samples
# Mutation ('XIV', 415071.0, 'T') not fixed in all samples
# Mutation ('XIV', 522888.0, 'C') not fixed in all samples
# Mutation ('XVI', 701723.0, 'C') not fixed in all samples
# There are 200 fixed differences between the ancestor and reference. Only 152 of these differences were fixed in evolved strains

# %%
#print data for alleles to check frequency and read depth
name = ('VIII', 21.0, 'ACCA')

all_alleles.get_group((name[0],int(name[1]),name[2]))
# Out:
#         Unnamed: 0 Chromosome  Position   Alt  Time  Ref  Is_repeat  \
# 8670          8670       VIII        21  ACCA     1  ACA          0
# 8671          8671       VIII        21  ACCA     3  ACA          0
# 8672          8672       VIII        21  ACCA     5  ACA          0
# 8673          8673       VIII        21  ACCA     7  ACA          0
# 8674          8674       VIII        21  ACCA     9  ACA          0
# 8675          8675       VIII        21  ACCA    12  ACA          0
# 28080        28080       VIII        21  ACCA     1  ACA          0
# 28081        28081       VIII        21  ACCA     3  ACA          0
# 28082        28082       VIII        21  ACCA     5  ACA          0
# 28083        28083       VIII        21  ACCA     7  ACA          0
# 28084        28084       VIII        21  ACCA     9  ACA          0
# 28085        28085       VIII        21  ACCA    12  ACA          0
# 47166        47166       VIII        21  ACCA     1  ACA          0
# 47167        47167       VIII        21  ACCA     3  ACA          0
# 47168        47168       VIII        21  ACCA     5  ACA          0
# 47169        47169       VIII        21  ACCA     7  ACA          0
# 47170        47170       VIII        21  ACCA     9  ACA          0
# 47171        47171       VIII        21  ACCA    12  ACA          0
# 67512        67512       VIII        21  ACCA     1  ACA          0
# 67513        67513       VIII        21  ACCA     3  ACA          0
# 67514        67514       VIII        21  ACCA     5  ACA          0
# 67515        67515       VIII        21  ACCA     7  ACA          0
# 67516        67516       VIII        21  ACCA     9  ACA          0
# 67517        67517       VIII        21  ACCA    12  ACA          0
# 88248        88248       VIII        21  ACCA     1  ACA          0
# 88249        88249       VIII        21  ACCA     3  ACA          0
# 88250        88250       VIII        21  ACCA     5  ACA          0
# 88251        88251       VIII        21  ACCA     7  ACA          0
# 88252        88252       VIII        21  ACCA     9  ACA          0
# 88253        88253       VIII        21  ACCA    12  ACA          0
# ...            ...        ...       ...   ...   ...  ...        ...
# 296304      296304       VIII        21  ACCA     1  ACA          0
# 296305      296305       VIII        21  ACCA     3  ACA          0
# 296306      296306       VIII        21  ACCA     5  ACA          0
# 296307      296307       VIII        21  ACCA     7  ACA          0
# 296308      296308       VIII        21  ACCA     9  ACA          0
# 296309      296309       VIII        21  ACCA    12  ACA          0
# 317928      317928       VIII        21  ACCA     1  ACA          0
# 317929      317929       VIII        21  ACCA     3  ACA          0
# 317930      317930       VIII        21  ACCA     5  ACA          0
# 317931      317931       VIII        21  ACCA     7  ACA          0
# 317932      317932       VIII        21  ACCA     9  ACA          0
# 317933      317933       VIII        21  ACCA    12  ACA          0
# 338394      338394       VIII        21  ACCA     1  ACA          0
# 338395      338395       VIII        21  ACCA     3  ACA          0
# 338396      338396       VIII        21  ACCA     5  ACA          0
# 338397      338397       VIII        21  ACCA     7  ACA          0
# 338398      338398       VIII        21  ACCA     9  ACA          0
# 338399      338399       VIII        21  ACCA    12  ACA          0
# 358434      358434       VIII        21  ACCA     1  ACA          0
# 358435      358435       VIII        21  ACCA     3  ACA          0
# 358436      358436       VIII        21  ACCA     5  ACA          0
# 358437      358437       VIII        21  ACCA     7  ACA          0
# 358438      358438       VIII        21  ACCA     9  ACA          0
# 358439      358439       VIII        21  ACCA    12  ACA          0
# 377514      377514       VIII        21  ACCA     1  ACA          0
# 377515      377515       VIII        21  ACCA     3  ACA          0
# 377516      377516       VIII        21  ACCA     5  ACA          0
# 377517      377517       VIII        21  ACCA     7  ACA          0
# 377518      377518       VIII        21  ACCA     9  ACA          0
# 377519      377519       VIII        21  ACCA    12  ACA          0
#
#         Read_depth  Num_ref  Num_alt  Freq_ref  Freq_alt  Qual_ref   Qual_alt  \
# 8670             3        0        0  0.000000  0.000000       0.0   2.000000
# 8671            12        1        4  0.200000  0.800000       2.0  28.000000
# 8672            17        0        8  0.000000  1.000000       0.0  32.500000
# 8673            10        0        4  0.000000  1.000000       0.0  35.000000
# 8674            13        0        5  0.000000  1.000000       0.0  35.200000
# 8675             7        1        0  0.142857  0.000000       0.0  35.200000
# 28080          NaN      NaN        0       NaN  0.000000       NaN        NaN
# 28081           11        0        3  0.000000  1.000000       0.0  31.666667
# 28082          NaN      NaN        0       NaN  0.000000       NaN        NaN
# 28083            7        0        3  0.000000  0.428571       0.0  32.000000
# 28084            8        0        3  0.000000  1.000000       0.0  37.000000
# 28085            5        0        0  0.000000  0.000000       0.0  37.000000
# 47166            2        0        0  0.000000  0.000000       0.0   2.000000
# 47167           14        0        3  0.000000  0.250000       0.0  29.666667
# 47168          NaN      NaN        0       NaN  0.000000       NaN        NaN
# 47169            7        0        3  0.000000  1.000000       0.0  27.666667
# 47170            3        0        0  0.000000  0.000000       0.0  27.666667
# 47171            5        0        0  0.000000  0.000000       0.0  27.666667
# 67512          NaN      NaN        0       NaN  0.000000       NaN        NaN
# 67513            6        0        0  0.000000  0.000000       0.0  23.333333
# 67514           12        0        7  0.000000  1.000000       0.0  33.857143
# 67515           10        1        3  0.100000  0.300000       2.0  37.000000
# 67516            3        0        0  0.000000  0.000000       0.0  37.000000
# 67517            5        0        3  0.000000  1.000000       0.0  30.000000
# 88248            2        0        0  0.000000  0.000000       0.0  10.666667
# 88249            9        3        0  0.333333  0.000000       0.0  10.666667
# 88250            7        0        0  0.000000  0.000000       0.0  10.666667
# 88251            9        2        3  0.400000  0.600000      33.5  21.333333
# 88252            5        1        0  0.200000  0.000000       0.0  21.333333
# 88253            9        0        2  0.000000  0.222222       0.0  37.000000
# ...            ...      ...      ...       ...       ...       ...        ...
# 296304           6        0        2  0.000000  1.000000       0.0  37.000000
# 296305          13        0        3  0.000000  1.000000       0.0  18.000000
# 296306         NaN      NaN        0       NaN  0.000000       NaN        NaN
# 296307           9        0        4  0.000000  1.000000       0.0  28.000000
# 296308           6        0        2  0.000000  1.000000       0.0  28.500000
# 296309           4        0        0  0.000000  0.000000       0.0  28.500000
# 317928           2        0        0  0.000000  0.000000       0.0  27.400000
# 317929         NaN      NaN        0       NaN  0.000000       NaN        NaN
# 317930          11        1        3  0.250000  0.750000      40.0  37.000000
# 317931           8        0        4  0.000000  1.000000       0.0  37.000000
# 317932           2        0        0  0.000000  0.000000       0.0  37.000000
# 317933           4        0        0  0.000000  0.000000       0.0  37.000000
# 338394           2        0        0  0.000000  0.000000       0.0   2.000000
# 338395          13        0        6  0.000000  1.000000       0.0  36.500000
# 338396           5        0        2  0.000000  1.000000       0.0  37.000000
# 338397           6        0        3  0.000000  1.000000       0.0  32.333333
# 338398           2        0        0  0.000000  0.000000       0.0  32.333333
# 338399           2        0        0  0.000000  0.000000       0.0  32.333333
# 358434         NaN      NaN        0       NaN  0.000000       NaN        NaN
# 358435           5        2        0  0.400000  0.000000       0.0  36.500000
# 358436          25        0        8  0.000000  1.000000       0.0  30.375000
# 358437         NaN      NaN        0       NaN  0.000000       NaN        NaN
# 358438         NaN      NaN        0       NaN  0.000000       NaN        NaN
# 358439           4        0        0  0.000000  0.000000       0.0  30.375000
# 377514         NaN      NaN        0       NaN  0.000000       NaN        NaN
# 377515          11        1        6  0.142857  0.857143      39.0  30.500000
# 377516           2        0        0  0.000000  0.000000       0.0  30.500000
# 377517          11        2        3  0.400000  0.600000      21.0  34.000000
# 377518           6        0        0  0.000000  0.000000       0.0  34.000000
# 377519           6        0        2  0.000000  1.000000       0.0  37.000000
#
#        Treatment  Strain
# 8670           C       1
# 8671           C       1
# 8672           C       1
# 8673           C       1
# 8674           C       1
# 8675           C       1
# 28080          C       2
# 28081          C       2
# 28082          C       2
# 28083          C       2
# 28084          C       2
# 28085          C       2
# 47166          C       3
# 47167          C       3
# 47168          C       3
# 47169          C       3
# 47170          C       3
# 47171          C       3
# 67512          C       4
# 67513          C       4
# 67514          C       4
# 67515          C       4
# 67516          C       4
# 67517          C       4
# 88248          C       5
# 88249          C       5
# 88250          C       5
# 88251          C       5
# 88252          C       5
# 88253          C       5
# ...          ...     ...
# 296304         H       6
# 296305         H       6
# 296306         H       6
# 296307         H       6
# 296308         H       6
# 296309         H       6
# 317928         H       7
# 317929         H       7
# 317930         H       7
# 317931         H       7
# 317932         H       7
# 317933         H       7
# 338394         H       8
# 338395         H       8
# 338396         H       8
# 338397         H       8
# 338398         H       8
# 338399         H       8
# 358434         H       9
# 358435         H       9
# 358436         H       9
# 358437         H       9
# 358438         H       9
# 358439         H       9
# 377514         H      10
# 377515         H      10
# 377516         H      10
# 377517         H      10
# 377518         H      10
# 377519         H      10
#
# [114 rows x 16 columns]

# %%
unique2P
# Out:
# [('MITO', 320, 'T'), ('XII', 944108, 'C'), ('XII', 1071409, 'C')]

# %%
#print parent alleles to check frequency and read depth
parent_grps = parent_df.groupby(['Chromosome','Position','Alt'])
name = ('XII', 1071409, 'C')
parent_grps.get_group((name[0],int(name[1]),name[2]))
# Out:
#     Chromosome  Position Ref Alt  Ref_count Alt_count  Ref_freq  Alt_freq  \
# 613        XII   1071409   A   C          0         2         0         1
#
#      N_calls
# 613        2

# %% [markdown]
# ## Conclusions
# - The majority of fixed alleles in the ancestor are also found at frequencies near 1 in nearly all samples and are therefore likely fixed in both.
# - All alleles fixed in ancestor but not present in other strains are in regions of very low sequencing depth and therefore explainable as high frequency sequencing errors.
# - Alleles that were not universally present at frequencies close to 1 in the samples seem to have low coverage in certain libraries, leading to high frequency sequencing errors, or regions where coverage was zero and therefore freqeuncy calls were labeled zero.
#
# ### In summary, there appear to be around 200 mutations differing between the ancestor and the S288C reference sequence and these are present in all experimental samples
